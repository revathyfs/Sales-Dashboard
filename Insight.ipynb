# %% [markdown]
# ## 🧭 **1. Dashboard Overview**
#
# This **Sales Dashboard** provides a **comprehensive visualization** of sales performance across various dimensions — time (months, quarters), product categories, sub-categories, payment modes, customers, and states.
# The **purpose** is to track total sales amount, quantity sold, profit — helping to identify high-performing areas and opportunities for improvement.
#
# ---
#
# ## 🧩 **2. KPI Cards (Top Section)**
#
# | KPI Metric                       | Value      | Description                                                     |
# | -------------------------------- | ---------- | --------------------------------------------------------------- |
# | 💰 **Total Amount**              | **438K**   | The total sales revenue generated.                              |
# | 📦 **Total Quantity**            | **5615**   | The total number of units/items sold across all categories.     |
# | 📈 **Total Profit**              | **37K**    | The overall profit after costs.                                 |
#
# 👉 **Interpretation:**
#
# * The business has moderate revenue with an average selling price of ₹875 per product.
# * Profit margins appear healthy, given the total amount vs. total profit.
#
# ---
#
# ## 🗓 **3. Quarter Filter**
#
# * Dropdown allows filtering by **Quarter (Q1, Q2, Q3, Q4)** or **All**.
# * This enables performance comparison between time periods.
#
# ---
#
# ## 🌍 **4. Total Amount by State (Top-Right Bar Chart)**
#
# **Insights:**
#
# * **Maharashtra** contributes the **highest sales** (~100K+).
# * Followed by **Madhya Pradesh**, **Uttar Pradesh**, and **Delhi**.
# * Lower sales are recorded in **Tamil Nadu**, **Goa**, and **Sikkim**.
#
# 👉 **Interpretation:**
#
# * Western and Central India are performing strongest.
# * Southern and North-Eastern states have growth potential.
#
# ---
#
# ## 📊 **5. Total Profit by Sub-Category (Left Bar Chart)**
#
# **Top Performing Sub-Categories:**
#
# * **Printers** yield the **highest profit**.
# * Other profitable items: **Bookcases, Sarees, Accessories, Tables**.
#
# **Low Performers:**
#
# * **Furnishings, Electronic Games, Kurtis, Skirts, T-shirts** show low profits.
#
# 👉 **Interpretation:**
#
# * Electronics (like printers) and furniture are profitable.
# * Some apparel sub-categories (like kurtis and t-shirts) may have low margins or low sales volume.
#
# ---
#
# ## 🥧 **6. Total Quantity by Category (Middle Donut Chart)**
#
# | Category       | % Share | Insights                                                   |
# | -------------- | ------- | ---------------------------------------------------------- |
# | 🧥 Clothing    | 62.62%  | Dominates sales volume (most items sold).                  |
# | 💻 Electronics | 20.55%  | Moderate contribution.                                     |
# | 🪑 Furniture   | 16.83%  | Least in quantity sold but may yield high profit per item. |
#
# 👉 **Interpretation:**
#
# * Clothing drives most sales volume.
# * Electronics and furniture might have **higher price per unit** but lower quantities.
#
# ---
#
# ## 💳 **7. Total Quantity by Payment Mode (Right Donut Chart)**
#
# | Payment Mode                               | % Share                                                                            | Interpretation                                      |
# | ------------------------------------------ | ---------------------------------------------------------------------------------- | --------------------------------------------------- |
# | **Mode 1 (Largest)**                       | 43.74%                                                                             | Most popular payment method — possibly Cash/Online. |
# | **Others (20.61%, 13.2%, 11.97%, 10.49%)** | Varying smaller portions — may include Credit Card, Debit Card, Wallets, UPI, etc. |                                                     |
#
# 👉 **Interpretation:**
#
# * Customers prefer one dominant payment mode (~44%).
# * Others are used less frequently — useful for targeted payment offers or discounts.
#
# ---
#
# ## 📅 **8. Total Profit by Month (Bottom-Left Bar Chart)**
#
# **Observations:**
#
# * **January and December** show **peak profits** (seasonal spikes, possibly festive seasons).
# * **April–August** shows **decline or stagnation** in profit.
# * Slight recovery in **September–October**.
#
# 👉 **Interpretation:**
#
# * The business might be **seasonal**, performing best around year-end holidays.
# * Mid-year months may need marketing pushes or discount strategies.
#
# ---
#
# ## 🗺 **9. Map Visualization (Center-Bottom)**
#
# * The **map of India** shows **sales distribution** by location (blue dots).
# * Dots likely represent **cities or states** with sales data.
#
# 👉 **Interpretation:**
#
# * Sales are spread across India, with **denser clusters in central and western India**.
# * Indicates national reach, not limited to one region.
#
# ---
#
# ## 👥 **10. Total Amount by Customer Name (Bottom-Right Bar Chart)**
#
# **Insights:**
#
# * Top customers include **Harshini, Mansi, Mahalakshmi, Varsha, and Vedika**.
# * The chart gradually decreases, indicating **a few high-value customers** (top-heavy sales distribution).
#
# 👉 **Interpretation:**
#
# * Pareto principle might apply — **20% of customers bring 80% of sales**.
# * Retaining and upselling to top customers can yield large gains.
#
# ---
#
# ## 🧮 **11. Summary of Key Insights**
#
# | Area                            | Insight                        | Recommendation                                       |
# | ------------------------------- | ------------------------------ | ---------------------------------------------------- |
# | 🏆 **Top State**                | Maharashtra                    | Focus marketing & logistics to maintain dominance.   |
# | 📈 **High Profit Sub-Category** | Printers, Bookcases            | Increase stock and promotions.                       |
# | 🧥 **Top Quantity Category**    | Clothing                       | Optimize pricing and bundle offers.                  |
# | 💳 **Top Payment Mode**         | 43.74% (likely online or cash) | Offer incentives for underused modes.                |
# | 🗓 **Peak Months**              | Jan & Dec                      | Plan campaigns and inventory before festive seasons. |
# | 👥 **Top Customers**            | Harshini, Mansi, Mahalakshmi   | Provide loyalty programs and personalized offers.    |
#
# ---
